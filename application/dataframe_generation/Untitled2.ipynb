# %%
library("stringr")
library("dplyr")
library("readr")
library("ggplot2")
library("purrr")
library("tidyr")

# %%
h16 = read_delim("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/haQTL_pure_completed_unlimited_16_99pCS.tsv")
m16 = read_delim("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/mQTL_pure_completed_unlimited_16_99pCS.tsv")

haQTL_affected_region = readr::read_delim("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping//all.haQTL.affected_region.tsv","\t")
mQTL_affected_region = readr::read_delim("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping//all.mQTL.affected_region.tsv","\t")
# Out:
# Rows: 21527 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (4): variants, ref, alt, molecular_trait_id
# dbl (11): snps_index, chromosome, position, cs_order, pip, finemapped_region...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 53860 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (4): variants, ref, alt, molecular_trait_id
# dbl (11): snps_index, chromosome, position, cs_order, pip, finemapped_region...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 14720 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# ...

# %%
susiF_obj_ha =  readRDS("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.tad75.uni_Fsusie.mixture_normal_per_scale.rds")

# %%
haQTL_affected_region = readr::read_delim("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping//all.haQTL.affected_region.tsv","\t")
mQTL_affected_region = readr::read_delim("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping//all.mQTL.affected_region.tsv","\t")
# Out:
# Rows: 14720 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): analysis, chr, molecular_trait_id
# dbl (3): CS, Start, End
# lgl (1): purity
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 89578 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): analysis, chr, molecular_trait_id
# dbl (3): CS, Start, End
# lgl (1): purity
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
which(map(susiF_obj_ha,~length(.x) == 5)%>%unlist)
# Out:
#   fitted_wc  fitted_wc2         lBF          KL   cred_band  alpha_hist
#           1           2           3           4           5           8
#       alpha          cs      est_pi      est_sd fitted_func      purity
#          13          14          16          17          28          30
#     runtime        time
#          31          32

# %%
dim(susiF_obj_ha$fitted_wc2[[5]])
# Out:
# [1] 3584  256

# %%
length(susiF_obj_ha$outing_grid)
# Out:
# [1] 256

# %%
h16_superf = read_delim("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/haQTL_pure_completed_unlimited_16_size_1.tsv")
# Out:
# Rows: 823 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (4): variants, ref, alt, molecular_trait_id
# dbl (11): snps_index, chromosome, position, cs_order, pip, finemapped_region...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
h16_superf%>%filter(molecular_trait_id == "tad635")
# Out:
#   variants                         snps_index chromosome position  ref
# 1 chr6:162716786_GCACA_GCACACACACA  4972      6          162716786 GCACA
# 2 chr6:164555139_C_T               10586      6          164555139 C
# 3 chr6:164740554_TAAA_TA           11269      6          164740554 TAAA
# 4 chr6:164931301_CACATAT_TACATAT   12086      6          164931301 CACATAT
#   alt         cs_order pip       molecular_trait_id finemapped_region_start
# 1 GCACACACACA 7        0.9597315 tad635             161400000
# 2 T           2        1.0000000 tad635             161400000
# 3 TA          8        0.9998727 tad635             161400000
# 4 TACATAT     3        1.0000000 tad635             161400000
#   finemapped_region_end purity is_dummy effect_peak_pos cs_size
# 1 165320000             1      0        161827382       1
# 2 165320000             1      0        164997270       1
# 3 165320000             1      0        165019359       1
# ...

# %%
haQTL_affected_region
# Out:
#       CS Start     End       analysis     chr   molecular_trait_id purity
# 1     1  2014812.3 2014812.3 rosmap_haqtl chr1  tad1               NA
# 2     1  2056493.6 2065798.9 rosmap_haqtl chr1  tad1               NA
# 3     1  2141402.3 2165187.8 rosmap_haqtl chr1  tad1               NA
# 4     1  2192041.5 2192041.5 rosmap_haqtl chr1  tad1               NA
# 5     1  2437928.6 2437928.6 rosmap_haqtl chr1  tad1               NA
# 6     1  2466041.8 2466041.8 rosmap_haqtl chr1  tad1               NA
# 7     1  3373659.3 3375569.6 rosmap_haqtl chr1  tad1               NA
# 8     1  3594738.4 3649557.9 rosmap_haqtl chr1  tad1               NA
# 9     1  2074311.8 2091992.2 rosmap_haqtl chr1  tad1               NA
# 10    1  2235013.4 2310878.7 rosmap_haqtl chr1  tad1               NA
# 11    1  2453685.3 2453685.3 rosmap_haqtl chr1  tad1               NA
# 12    1  3454010.1 3491796.8 rosmap_haqtl chr1  tad1               NA
# ...

# %%
region_candidates = inner_join(by = ,h16_superf%>%count(molecular_trait_id,cs_order)%>%rename(CS = cs_order),haQTL_affected_region%>%group_by(CS,molecular_trait_id)%>%mutate(length = End - Start)%>%summarize(mean(length), IQR = range(length)))
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'CS', 'molecular_trait_id'. You can
# override using the `.groups` argument.
# Joining with `by = join_by(molecular_trait_id, CS)`

# %%
ENSG00000128284

# %%
region_candidates = inner_join( h16_superf%>%count(molecular_trait_id,cs_order)%>%rename(CS = cs_order)%>%select(-n),haQTL_affected_region%>%group_by(CS,molecular_trait_id)%>%mutate(length = End - Start)%>%summarize(mean(length),median(length),max(length), n = sum(length>mean(length))))
# Out:
# `summarise()` has grouped output by 'CS'. You can override using the `.groups`
# argument.
# Joining with `by = join_by(molecular_trait_id, CS)`

# %%
eQ

# %%
region_candidates%>%filter(n>1)%>%filter(molecular_trait_id %in% c("tad75","tad185","tad426","tad435"))
# Out:
#   molecular_trait_id CS mean(length) median(length) max(length) n
# 1 tad75              5  19338.5      8461.001       67050.76    2

# %%
susiF_obj_ha =  readRDS("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.tad185.uni_Fsusie.mixture_normal_per_scale.rds")

# %%
region_candidates = region_candidates%>%mutate(path = paste0("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.",molecular_trait_id,".uni_Fsusie.mixture_normal_per_scale.rds"))

# %%
region_candidates_df = region_candidates%>%mutate(plot_df = map2(path,CS, ~readRDS(.x)%>%effect_extract_df(n = .y) ))

# %%
region_candidates%>%arrange(-`median(length)`)
# Out:
#     molecular_trait_id CS mean(length) median(length) max(length) n
# 1   tad1370             7 558411.5     444228.7       1373349.9   2
# 2   tad895              1 605996.7     432879.6       1113934.4   1
# 3   tad277              3 320632.2     388291.0        550799.6   3
# 4   tad124              3 456009.6     341303.1       1135077.1   2
# 5   tad1217             5 336890.4     340099.1        430965.1   2
# 6   tad272              1 286281.7     269975.3        561651.6   2
# 7   tad1127             1 266988.6     266988.6        524433.2   1
# 8   tad1252             1 314347.1     219842.6        817703.3   2
# 9   tad1334             5 178677.3     204749.4        384512.7   4
# 10  tad1303             4 202913.0     202913.0        403452.1   1
# 11  tad1400            14 205003.3     200751.2        403684.5   3
# 12  tad66               6 266213.5     188099.0        668214.4   2
# 13  tad774              1 167900.8     186169.0        249805.9   3
# ...

# %%
getwd()
# Out:
# [1] "/mnt/vast/hpc/homes/hs3163/GIT/neuro-mQTL/notebook"

# %%
options(repr.plot.width =30, repr.plot.height = 20)

# %%
(region_candidates_df%>%filter(molecular_trait_id == "tad1284",CS == 2 )%>%pull(plot_df))[[1]]%>%plot_effect
# Out:
# plot without title

# %%
3_tad_1217_5 = readRDS("")

# %%
susiF_obj_ha2 =   readRDS("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.tad635.uni_Fsusie.mixture_normal_per_scale.rds")
genotype_ha2= readRDS("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/rerun/cache//fsusie.rosmap_haqtl.tad635.uni_Fsusie.mixture_normal_per_scale.rds")
susiF_obj_ha2$input_data = genotype_ha2$input_data
list(tad1217_5 = susiF_obj_ha, tad653_3 =  susiF_obj_ha2)%>%saveRDS("3_two_peak_ha_rawdata.rds")

# %%
susiF_obj_ha =   readRDS("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.tad174.uni_Fsusie.mixture_normal_per_scale.rds")
genotype_ha= readRDS("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/rerun/cache//fsusie.rosmap_haqtl.tad174.uni_Fsusie.mixture_normal_per_scale.rds")
susiF_obj_ha$input_data = genotype_ha$input_data

# %%
list(tad174_1 = susiF_obj_ha)%>%saveRDS("3_tad174_ha_rawdata.rds")

# %%
genotype_ha$cs

# %%
susiF_obj_ha$cs
# Out:
# [[1]]
# chr2:86208944_C_A
#              2204
#
# [[2]]
#                            chr2:85902843_A_AT
#                                          1490
# chr2:85917782_GATAAATAA_GATAAATAAATAAATAAATAA
#                                          1567
#
# [[3]]
#    chr2:86703843_G_T chr2:86703126_CA_CAA    chr2:86696055_A_G
#                 3174                 3173                 3163
#
# [[4]]
# chr2:85843250_A_G chr2:85843251_T_C chr2:85844729_A_T chr2:85844741_G_A
#              1271              1272              1276              1277
# chr2:85862550_A_T chr2:85863908_C_T chr2:85868556_C_G chr2:85872482_C_A
#              1342              1347              1363              1384
# chr2:85905908_T_C chr2:85893855_C_G chr2:85898176_G_A chr2:85874897_T_A
#              1510              1459              1476              1394
#
# [[5]]
#             chr2:85537843_A_T             chr2:85537845_T_G
#                           457                           458
# ...

# %%
susiF.alpha::plot_susiF(susiF_obj_ha2%>%update_credible_band)

# %%
susiF.alpha::plot_susiF(susiF_obj_ha%>%update_cal_credible_band2)
# Out:
# Error in match.names(clabs, names(xi)): names do not match previous names
# Traceback:
#
# 1. susiF.alpha::plot_susiF(susiF_obj_ha %>% update_cal_credible_band2)
# 2. rbind(data.frame(up = rep(0, n_wac), low = rep(0, n_wac)), cred_band)
# 3. rbind(deparse.level, ...)
# 4. match.names(clabs, names(xi))
# 5. stop("names do not match previous names")

# %%
susiF_obj_ha%>%effect_extract_df(1)%>%plot_effect
# Out:
# New names:
# • `` -> `...1`
# plot without title

# %%
susiF_obj_ha$cs
# Out:
# [[1]]
# chr2:86208944_C_A
#              2204
#
# [[2]]
#                            chr2:85902843_A_AT
#                                          1490
# chr2:85917782_GATAAATAA_GATAAATAAATAAATAAATAA
#                                          1567
#
# [[3]]
#    chr2:86703843_G_T chr2:86703126_CA_CAA    chr2:86696055_A_G
#                 3174                 3173                 3163
#
# [[4]]
# chr2:85843250_A_G chr2:85843251_T_C chr2:85844729_A_T chr2:85844741_G_A
#              1271              1272              1276              1277
# chr2:85862550_A_T chr2:85863908_C_T chr2:85868556_C_G chr2:85872482_C_A
#              1342              1347              1363              1384
# chr2:85905908_T_C chr2:85893855_C_G chr2:85898176_G_A chr2:85874897_T_A
#              1510              1459              1476              1394
#
# [[5]]
#             chr2:85537843_A_T             chr2:85537845_T_G
#                           457                           458
# ...

# %%
a$cs
# Out:
# [[1]]
# chr2:86208944_C_A
#              2204
#
# [[2]]
#                            chr2:85902843_A_AT
#                                          1490
# chr2:85917782_GATAAATAA_GATAAATAAATAAATAAATAA
#                                          1567
#
# [[3]]
#    chr2:86703843_G_T chr2:86703126_CA_CAA    chr2:86696055_A_G
#                 3174                 3173                 3163
#
# [[4]]
# chr2:85843250_A_G chr2:85843251_T_C chr2:85844729_A_T chr2:85844741_G_A
#              1271              1272              1276              1277
# chr2:85862550_A_T chr2:85863908_C_T chr2:85868556_C_G chr2:85872482_C_A
#              1342              1347              1363              1384
# chr2:85905908_T_C chr2:85893855_C_G chr2:85898176_G_A chr2:85874897_T_A
#              1510              1459              1476              1394
#
# [[5]]
#             chr2:85537843_A_T             chr2:85537845_T_G
#                           457                           458
# ...

# %%
susiF_obj_ha$cs
# Out:
# [[1]]
# chr15:92734199_C_G
#               9951
#
# [[2]]
# chr15:91104210_T_G
#               4794
#
# [[3]]
# chr15:91664536_A_C
#               6413
#
# [[4]]
# chr15:90295161_C_T
#               2052
#
# [[5]]
# chr15:92624920_G_A
#               9533
#
# [[6]]
# chr15:90955016_A_C chr15:90955063_G_A chr15:90955051_C_T
#               4261               4263               4262
#
# [[7]]
# chr15:92737247_G_T chr15:92703941_A_G chr15:92704183_C_T
#               9965               9775               9776
#
# [[8]]
# chr15:89751058_T_G
#                417
#
# [[9]]
# chr15:92443849_T_A
#               8779

# %%
map(head(region_candidates_df%>%mutate(dist =  `median(length)`-`mean(length)` )%>%arrange(-n ))%>%pull(plot_df),~.x%>%plot_effect)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# [[1]]
#
# [[2]]
#
# [[3]]
#
# [[4]]
#
# [[5]]
#
# [[6]]
# plot without title
# plot without title

# %%
head(region_candidates_df%>%arrange(-`max(length)`))%>%select(-plot_df)
# Out:
#   molecular_trait_id CS mean(length) median(length) max(length) n
# 1 tad635              3 499438.8      21346.89      2772237     1
# 2 tad764              2 492458.8      25241.94      2383293     1
# 3 tad1127             2 450247.5      33369.57      1946910     1
# 4 tad1345             3 263896.8      17571.98      1508948     2
# 5 tad861             12 503416.2     166909.37      1426581     2
# 6 tad1370             7 558411.5     444228.70      1373350     2
#   path
# 1 /mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.tad635.uni_Fsusie.mixture_normal_per_scale.rds
# 2 /mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.tad764.uni_Fsusie.mixture_normal_per_scale.rds
# 3 /mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.tad1127.uni_Fsusie.mixture_normal_per_scale.rds
# ...

# %%
order(-c(11,2,3))
# Out:
# [1] 1 3 2

# %%
options(repr.plot.width =30, repr.plot.height = 5)

# %%
map(head(region_candidates%>%arrange(-`max(length)`)%>%mutate(plot_df = map2(path,CS, ~readRDS(.x)%>%effect_extract_df(n = .y) )) )%>%pull(plot_df),~.x%>%plot_effect)
# Out:
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`
# New names:
# • `` -> `...1`

# %%
region_candidates_df_test = region_candidates_df%>%unnest(plot_df)

# %%
(region_candidates_df%>%filter(molecular_trait_id == "tad174",CS == 1 )%>%pull(path))[[1]]
# Out:
# [1] "/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.tad174.uni_Fsusie.mixture_normal_per_scale.rds"

# %%
a = readRDS("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.tad174.uni_Fsusie.mixture_normal_per_scale.rds")%>%update_cal_credible_band2

# %%
susiF.alpha::plot_susiF(readRDS("/mnt/vast/hpc/csg/molecular_phenotype_calling/QTL_fine_mapping/output/definitive_haQTL/haQTL.rosmap_haqtl.tad174.uni_Fsusie.mixture_normal_per_scale.rds"))
# Out:
# plot without title
# plot without title

# %%
(region_candidates_df%>%filter(molecular_trait_id == "tad1059",CS == 1 )%>%pull(plot_df))[[1]]%>%plot_effect
# Out:
# plot without title

# %%
(region_candidates_df%>%filter(molecular_trait_id == "tad116",CS == 2 )%>%pull(plot_df))[[1]]%>%plot_effect
# Out:
# plot without title

# %%
(region_candidates_df%>%filter(molecular_trait_id == "tad486",CS == 2 )%>%pull(plot_df))[[1]]%>%plot_effect
# Out:
# plot without title

# %%
(region_candidates_df%>%filter(molecular_trait_id == "tad1228",CS == 1 )%>%pull(plot_df))[[1]]%>%plot_effect
# Out:
# plot without title

# %%
(region_candidates_df%>%filter(molecular_trait_id == "tad106",CS == 2 )%>%pull(plot_df))[[1]]%>%plot_effect
# Out:
# plot without title

# %%
(region_candidates_df%>%filter(molecular_trait_id == "tad495",CS == 1 )%>%pull(plot_df))[[1]]%>%plot_effect
# Out:
# plot without title

# %%
(region_candidates_df%>%filter(molecular_trait_id == "tad175",CS == 1 )%>%pull(plot_df))[[1]]%>%plot_effect
# Out:
# plot without title

# %%
region_candidates_df_test%>%group_by(molecular_trait_id,n, CS)%>%summarise(top = order(-abs(mid))[1], mid[top],top2 = order(-abs(mid))[2],mid[top2] , count = n()  )%>%mutate(diff =  abs(`mid[top]`) - abs(`mid[top2]`),dist = abs(top2-top)/count)%>%arrange( -abs(`mid[top2]`) )%>%filter(abs(`mid[top2]`) >= 0.09, top != count, top2 != count,dist >= 0.1)
# Out:
# `summarise()` has grouped output by 'molecular_trait_id', 'n'. You can override
# using the `.groups` argument.
#   molecular_trait_id n  CS top mid[top]   top2 mid[top2]   count diff
# 1 tad174              8 1  150  0.2269451 113  -0.18759376 256   0.039351341
# 2 tad116             NA 2   11  0.3330638   7   0.18059910  32   0.152464671
# 3 tad1059            NA 1   19 -0.2110099  24  -0.12641542  32   0.084594438
# 4 tad486              1 2  242  0.1710316 207  -0.11933386 256   0.051697689
# 5 tad100              2 1   29 -0.1000394  16   0.09851002  64   0.001529355
#   dist
# 1 0.1445312
# 2 0.1250000
# 3 0.1562500
# 4 0.1367188
# 5 0.2031250

# %%
(region_candidates_df%>%filter(molecular_trait_id == "tad100",CS == 1 )%>%pull(plot_df))[[1]]%>%plot_effect
# Out:
# plot without title

# %%
region_candidates_df%>%saveRDS("region_candidate_df.rds")

# %%
a = attach("superfine_casestudy/tad75.RData")

# %%
a$a$haQTL

# %%
susiF.alpha::plot_susiF(a$a$haQTL)
# Out:
# plot without title
# plot without title

# %%
effect_extract_df(a$a$haQTL , 5)
# Out:
# New names:
# • `` -> `...1`
# plot without title

# %%
 color = c("black", "dodgerblue2", "green4", "#6A3D9A",
      "#FF7F00", "gold1", "skyblue2", "#FB9A99", "palegreen2",
      "#CAB2D6", "#FDBF6F", "gray70", "khaki2", "maroon", "orchid1",
      "deeppink1", "blue1", "steelblue4", "darkturquoise", "green1",
      "yellow4", "yellow3","darkorange4","brown","navyblue","#FF0000",
      "darkgreen","#FFFF00","purple","#00FF00","pink","#0000FF",
      "orange","#FF00FF","cyan","#00FFFF","#FFFFFF")

# %%
plot_effect = function(plot_df){
plot = plot_df%>%arrange(-abs(mid))%>%group_by(effect)%>%ggplot(linewidth = 7)+
     geom_line(aes(x = pos, y = mid,color = effect))+geom_ribbon(aes(x = pos, y = mid,ymin = low, ymax = up,fill = effect), alpha = 0.2)+
         ylab("Estimated Effect") + xlab("POS")+geom_hline(aes(yintercept = 0), color = "black")+theme_bw()+
         xlab("") + facet_grid(effect ~.)+scale_color_manual("Credible set",values = color[c(1,8)+1])+
         ylab("Estimated Effect")+ scale_fill_manual("Credible set",values = color[c(1,8)+1])+
         theme(text = element_text(size = 40))+  theme(plot.margin=unit(c(5,0,0,0),"mm"), strip.text.y.right = element_text(angle = 0,size = 20),axis.text.x = element_blank(),axis.text.y = element_text(size = 25))
return(plot)
}
